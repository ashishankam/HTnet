# %%
import torch
from torchvision import models

# Load the state dictionary
state_dict = torch.load(r'E:\HTnet\HTNet-master\ourmodel_threedatasets_weights\007.pth')
print(state_dict)
# Print keys to understand the structure
# print(state_dict)

# # Example: Loading into a model (like ResNet18)
# model = models.resnet18()  # Adjust based on your model architecture
# model.load_state_dict(state_dict)
# print(model)  # View the model structure
# Out:
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_19364\1890836148.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import torch
from Model import HTNet  # Replace with your model file and class name
from torchvision import transforms
from PIL import Image

# Initialize the model
model = HTNet()

# Load the state dictionary (weights)
state_dict = torch.load(r'E:\HTnet\HTNet-master\ourmodel_threedatasets_weights\007.pth')
model.load_state_dict(state_dict)

# Set the model to evaluation mode
model.eval()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       4 from PIL import Image
#       6 # Initialize the model
# ----> 7 model = HTNet()
#       9 # Load the state dictionary (weights)
#      10 state_dict = torch.load(r'E:\HTnet\HTNet-master\ourmodel_threedatasets_weights\007.pth')
#
# TypeError: __init__() missing 7 required keyword-only arguments: 'image_size', 'patch_size', 'num_classes', 'dim', 'heads', 'num_hierarchies', and 'block_repeats'
